# %%
import logging
import os.path
import sys
import multiprocessing
from gensim.corpora import WikiCorpus
from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:865: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Using TensorFlow backend.

# %%
program = os.path.basename('train_word2vec_model')
logger = logging.getLogger(program)
logging.basicConfig(format='%(asctime)s: %(levelname)s: %(message)s')
logging.root.setLevel(level=logging.INFO)
logger.info("running %s" % ' '.join(sys.argv))
# Out:
# 2018-04-04 21:36:42,377: INFO: running /home/zzz/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py -f /run/user/1001/jupyter/kernel-bdde2c12-c652-46ea-bb7e-aa5da7b28548.json

# %%
inp='data/nolabel_text_process_seg_500w.csv'
outp='model/word2vec_model_100d'
n_dim=100
model = Word2Vec(LineSentence(inp), size=n_dim, window=5, min_count=5,
            workers=multiprocessing.cpu_count())
model.save(outp)
# Out:
# 2018-04-04 21:36:42,466: INFO: collecting all words and their counts
# 2018-04-04 21:36:42,468: INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-04-04 21:36:42,657: INFO: PROGRESS: at sentence #10000, processed 335432 words, keeping 20229 word types
# 2018-04-04 21:36:42,873: INFO: PROGRESS: at sentence #20000, processed 729231 words, keeping 30021 word types
# 2018-04-04 21:36:43,065: INFO: PROGRESS: at sentence #30000, processed 1073046 words, keeping 37966 word types
# 2018-04-04 21:36:43,252: INFO: PROGRESS: at sentence #40000, processed 1406575 words, keeping 43299 word types
# 2018-04-04 21:36:43,438: INFO: PROGRESS: at sentence #50000, processed 1735959 words, keeping 46536 word types
# 2018-04-04 21:36:43,629: INFO: PROGRESS: at sentence #60000, processed 2082184 words, keeping 50662 word types
# 2018-04-04 21:36:43,804: INFO: PROGRESS: at sentence #70000, processed 2392243 words, keeping 53779 word types
# ...

# %%
import gensim
model = gensim.models.Word2Vec.load("model/word2vec_model_200d")
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:865: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Using TensorFlow backend.

# %%
model['奇葩']
# Out:
# array([ -1.42146862e+00,   6.78366601e-01,  -1.90617427e-01,
#         -2.06593823e+00,  -3.54206651e-01,   6.01452053e-01,
#         -7.29463220e-01,   2.07199192e+00,   5.03704846e-01,
#          2.97569633e-01,  -3.77907604e-01,   4.20796812e-01,
#          1.06867266e+00,   3.12387675e-01,   1.76703763e+00,
#          1.78366947e+00,  -3.12874466e-01,  -1.27438092e+00,
#          7.01032519e-01,  -3.52471918e-01,   1.05318916e+00,
#         -1.21971154e+00,  -8.43331933e-01,  -2.94440055e+00,
#         -7.32982278e-01,   4.40560095e-02,   7.31707215e-01,
#          9.19878762e-03,  -3.16387475e-01,  -1.79925871e+00,
#         -1.85344055e-01,   2.21593976e+00,  -1.01884687e+00,
#          1.23299682e+00,   2.39221260e-01,  -5.39209425e-01,
#          1.09496284e+00,  -1.29774362e-01,   3.30903196e+00,
#          2.23859501e+00,  -8.61568630e-01,   8.09669077e-01,
#          7.88139820e-01,   8.70827556e-01,  -2.99517694e-03,
# ...

# %%
result = model.most_similar(u"奇葩")
for e in result:
    print(e[0],e[1])
# Out:
# 闻所未闻 0.5314355492591858
# 匪夷所思 0.527378499507904
# 极品 0.5107696056365967
# 丧心病狂 0.49290767312049866
# 凶残 0.47631216049194336
# 缺德 0.47590285539627075
# 神奇 0.4753618836402893
# 怪异 0.4692336618900299
# 不可思议 0.4634648263454437
# 可笑 0.45881474018096924

# %%
result = model.most_similar(u"[哈哈]")
for e in result:
    print(e[0],e[1])
# Out:
# [嘻嘻] 0.892831563949585
# [偷笑] 0.8452258110046387
# 哈哈 0.785342812538147
# [笑哈哈] 0.7387429475784302
# [酷] 0.7373462915420532
# 哈哈哈 0.7103936076164246
# [USER_MENTION] 0.6898242235183716
# [挖鼻屎] 0.6794920563697815
# : 0.6355744004249573
# [阴险] 0.6277317404747009

# %%
result = model.most_similar(u"[偷笑]")
for e in result:
    print(e[0],e[1])
# Out:
# [嘻嘻] 0.884958803653717
# [哈哈] 0.8452258110046387
# [挖鼻屎] 0.8149065971374512
# [酷] 0.808819591999054
# [阴险] 0.7897383570671082
# [害羞] 0.7684028148651123
# 哈哈 0.7640156745910645
# [做鬼脸] 0.7140945792198181
# [偷乐] 0.7081232070922852
# 嘿嘿 0.7006151080131531

# %%
print (model.doesnt_match(u"早餐 晚餐 午餐 中心".split()))
# Out:
# 中心
